# %%
import os

# %%
import detect_audio as da

# %%
import showWave2 as sw

# %%
import play_wave as pw

# %%
# Out:
# 256

# %%
os.system('python ./showWave2.py temp_wav/test.wav')
# Out:
# 256

# %%
#pocket voice
os.system('python3 ./play_wave.py wav temp_wav/test')
sw.show_wave('temp_wav/test.wav')
# Out:
# [ 18  17  15  15  12   5   6   6  -1  -1  -4  -8  -7 -11 -17 -18 -20 -25
#  -28 -30 -34 -36 -39 -40 -40 -46 -49 -48 -49 -47]

# %%
#me voice
os.system('python3 ./play_wave.py wav temp_wav/test2')
sw.show_wave('temp_wav/test2.wav')
# Out:
# [-10  -9 -10 -12 -10 -11 -15 -14 -14 -12 -11  -5  -3  -5  -1   0   2   2
#    4  11  10  10   8   4   7  13  13  11  10  11]

# %%
#anan voice
os.system('python3 ./play_wave.py wav temp_wav/news_anan')
sw.show_wave('temp_wav/news_anan.wav')
# Out:
# [  64   22  -22  -40  -25   -9   14   47   87  155  210  242  256  228  192
#   153  119   94   34  -14  -31  -12    0  -58 -128 -164 -140  -80  -51  -49]

# %%
#yoyo voice
sw.show_wave('temp_wav/news1.wav')
# Out:
# [-187 -102  -11   47   57   24  -24  -58  -54  -21   23   62   91  120  144
#   168  177  163  129   81   40   25   31   45   60   72   85   97   98   81]

# %%
#gooogle voice
os.system('python3 ./play_wave.py wav temp_wav/news_google')
sw.show_wave('temp_wav/news_google.wav')
# Out:
# [-324 -245  773  605 -405  183 -479 -490  267 -108  202  713 -220 -364 -218
#  -825  368   69 -112  360 -355  139 -244 -133  345 -629 -495  420  192  -91]

# %%
#combine aiai voice
os.system('python3 ./play_wave.py wav temp4/combine_slice')
sw.show_wave('temp4/combine_slice.wav')
# Out:
# [ -222  -359  -532  -787 -1090 -1311 -1480 -1650 -1844 -2015 -2116 -2194
#  -2182 -2116 -2092 -2045 -1922 -1699 -1487 -1292  -999  -725  -483  -209
#     22   244   492   742   985  1235]

# %%
#combine anan voice
os.system('python3 ./play_wave.py wav temp5/combine_slice')
sw.show_wave('temp5/combine_slice.wav')
# Out:
# [ 427  402  372  344  309  249  181  120   59   -4  -83 -175 -281 -391 -485
#  -563 -637 -697 -754 -803 -836 -852 -857 -861 -849 -813 -776 -732 -669 -597]
